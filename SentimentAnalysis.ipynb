# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Architecture of the model
#
#     Dataset:
#      train - 3235,6
#      test  -
#
#     Input: (count of words in a tweet, batch_size, seq_length of word)
#     hidden: (256)
#     output: (batch_size, 1)

# %%
#Importing key libraries
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import os

# %%
path = '/data'
file_name = 'train.csv'
file_path = os.path.join(path, file_name)

# %%
dataset = pd.read_csv(file_path)
print(dataset.shape)
# Out:
# (3235, 6)

# %%
dataset.sample(4)
# Out:
#                 id                                      original_text lang  \
# 926   1.245019e+18  Happy mother's Day everyone :) What are you gu...   en
# 1488  1.246527e+18  Good morning and Happy day 1 lockdown! My apol...   en
# 1934  1.245011e+18  Our beautiful swing gals doin our thang for mo...   en
# 1142  1.245415e+18  We would like to say Happy Mothers Day to all!...   en
#
#      retweet_count  original_author  sentiment_class
# 926              0        Fred_Bot_                1
# 1488             0   huntsvillepage                0
# 1934             1  8thlinecreation               -1
# 1142             0  LiveGoodProduct                0

# %%
tweets = dataset['original_text']
sentiments = dataset['sentiment_class']

# %% [markdown]
# ### preprocessing tweets

# %%
all_tweets = ''.join(tweets)
print(all_tweets[:200])
# Out:
# Happy #MothersDay to all you amazing mothers out there! I know it's hard not being able to see your mothers today but it's on all of us to do what we can to protect the most vulnerable members of our

# %%
tweets[:3]
# Out:
# 0    Happy #MothersDay to all you amazing mothers o...
# 1    Happy Mothers Day Mum - I'm sorry I can't be t...
# 2    Happy mothers day To all This doing a mothers ...
# Name: original_text, dtype: object

# %%
#removing the punctuations
punc = '!@#-)(_$;:/'
tweets_punc = []
for tweet in tweets:
    t = [c.lower() for c in tweet.split(' ') if c not in punc]
    tw = ' '.join(t)
    tweets_punc.append(tw)
    
print(len(tweets_punc))
# Out:
# 3235

# %%
print(len(all_tweets.split(' ')))
# Out:
# 108215

# %%
all_tweets_punc = ' '.join(tweets_punc)
print(len(all_tweets_punc.split(' ')))
# Out:
# 110968

# %%
#Counting total number of words
from collections import Counter
words = all_tweets_punc.split(' ')
total_words = len(words)

count_words = Counter(words)
sorted_words = count_words.most_common(total_words)

# %%
sorted_words
# Out:
# [('to', 3926),
#  ('happy', 3413),
#  ('day', 3293),
#  ('the', 3015),
#  ('and', 2579),
#  ('mothers', 2424),
#  ('you', 2259),
#  ('all', 2044),
#  ('a', 1854),
#  ('#mothersday', 1593),
#  ('my', 1322),
#  ('…', 1230),
#  ('of', 1192),
#  ('i', 1154),
#  ('for', 1149),
#  ('in', 1046),
#  ('we', 956),
#  ('https://www.', 868),
#  ('.', 861),
#  ('love', 740),
#  ('your', 677),
#  ('are', 676),
#  ('out', 670),
#  ('is', 654),
#  ('our', 634),
#  ('this', 605),
#  ("mother's", 601),
#  ('mother’s', 593),
#  ('mum', 590),
#  ('with', 583),
#  ('have', 574),
#  ('be', 548),
#  ('so', 486),
#  ('mums', 480),
#  ('her', 479),
#  ('but', 454),
#  ('from', 429),
#  ('who', 426),
#  ('that', 399),
#  ('at', 388),
#  ('me', 387),
#  ('on', 386),
#  ('&', 379),
#  ('it', 343),
#  ('today', 329),
#  ('not', 324),
#  ('there', 310),
#  ('amazing', 307),
#  ('us', 294),
#  ('as', 292),
#  ('hope', 287),
#  ('mother', 284),
#  ('thank', 276),
#  ('she', 272),
#  ('their', 264),
#  ('https://', 262),
#  ('#mothersday2020', 258),
#  ('wonderful', 249),
#  ('do', 241),
#  ('those', 225),
#  ('very', 216),
#  ('one', 212),
#  ('#happymothersday', 211),
#  ('best', 211),
#  ('just', 206),
#  ('like', 205),
#  ('know', 201),
#  ('beautiful', 197),
#  ('wish', 197),
#  ('can', 192),
#  ('stay', 191),
#  ('was', 191),
#  ('day!', 190),
#  ('lovely', 190),
#  (',', 181),
#  ('or', 181),
#  ('will', 179),
#  ('every', 173),
#  ('much', 172),
#  ('always', 170),
#  ('see', 166),
#  ('#motheringsunday', 160),
#  ('had', 157),
#  ('safe', 156),
#  ('when', 155),
#  ('they', 154),
#  ('how', 151),
#  ('being', 148),
#  ('no', 148),
#  ('if', 147),
#  ('special', 143),
#  ('up', 143),
#  ('world', 142),
#  ('everyone', 141),
#  ('day.', 141),
#  ('would', 141),
#  ('time', 139),
#  ('an', 138),
#  ('what', 137),
#  ('them', 137),
#  ('been', 133),
#  ('great', 132),
#  ('women', 132),
#  ('celebrate', 132),
#  ('has', 129),
#  ('may', 128),
#  ('by', 128),
#  ('here', 127),
#  ('more', 125),
#  ('get', 122),
#  ('wishing', 121),
#  ('these', 121),
#  ('there.', 121),
#  ("it's", 119),
#  ('keep', 119),
#  ('still', 119),
#  ('#love', 119),
#  ('everything', 115),
#  ('some', 112),
#  ('x', 111),
#  ('most', 109),
#  ('family', 109),
#  ('even', 108),
#  ("i'm", 107),
#  ('without', 105),
#  ('you.', 104),
#  ('good', 104),
#  ('mums,', 101),
#  ('say', 99),
#  ('children', 97),
#  ('mom', 96),
#  ('other', 96),
#  ('over', 96),
#  ('#mum', 95),
#  ('make', 94),
#  ('take', 94),
#  ('about', 92),
#  ('now', 91),
#  ('there!', 89),
#  ('thanks', 89),
#  ('loved', 87),
#  ('#mothers', 85),
#  ('today.', 84),
#  ('xx', 84),
#  ('also', 83),
#  ('little', 82),
#  ('am', 82),
#  ('year', 82),
#  ("you're", 82),
#  ('ones', 82),
#  ('people', 80),
#  ('through', 80),
#  ('able', 79),
#  ('#happymothersday2020', 79),
#  ('especially', 79),
#  ('made', 78),
#  ('mothers,', 78),
#  ('could', 78),
#  ("mothers'", 78),
#  ('home', 78),
#  ('mum,', 78),
#  ('uk', 78),
#  ('many', 77),
#  ("can't", 75),
#  ('life', 75),
#  ('please', 75),
#  ('woman', 75),
#  ('care', 74),
#  ('doing', 73),
#  ('#family', 73),
#  ('give', 73),
#  ('never', 72),
#  ('only', 72),
#  ('it’s', 72),
#  ('than', 72),
#  ('mum.', 71),
#  ('world.', 70),
#  ('there,', 70),
#  ('you,', 70),
#  ('xxx', 69),
#  ('times', 69),
#  ('working', 69),
#  ('u', 69),
#  ('appreciate', 69),
#  ('got', 68),
#  ('miss', 68),
#  ('big', 67),
#  ('god', 67),
#  ('want', 67),
#  ('because', 67),
#  ('go', 67),
#  ('sunday', 66),
#  ('call', 66),
#  ('day,', 66),
#  ('first', 66),
#  ('#mother', 65),
#  ('enjoy', 65),
#  ('mummy', 64),
#  ('after', 64),
#  ('ever', 64),
#  ('lost', 63),
#  ('today,', 63),
#  ('lots', 62),
#  ("mum's", 62),
#  ('together', 61),
#  ('going', 60),
#  ('well', 60),
#  ("don't", 60),
#  ('around', 59),
#  ('having', 59),
#  ('sending', 59),
#  ('i’m', 59),
#  ('own', 58),
#  ('look', 58),
#  ('both', 56),
#  ('hard', 55),
#  ('flowers', 55),
#  ('all.', 55),
#  ('last', 55),
#  ('sure', 54),
#  ('mama', 54),
#  ('back', 54),
#  ('#stayathome', 54),
#  ('need', 53),
#  ('kids', 53),
#  ('#staysafe', 53),
#  ('years', 53),
#  ('families', 53),
#  ('its', 52),
#  ('any', 51),
#  ('were', 51),
#  ('social', 51),
#  ('lucky', 51),
#  ('mothering', 51),
#  ('where', 51),
#  ('#covidー19', 50),
#  ('can’t', 50),
#  ('things', 50),
#  ('celebrating', 49),
#  ('support', 49),
#  ('let', 49),
#  ('us.', 49),
#  ('2', 49),
#  ('next', 48),
#  ('spend', 48),
#  ('too', 48),
#  ('really', 48),
#  ('he', 47),
#  ('looking', 47),
#  ('difficult', 47),
#  ('moms', 47),
#  ('mothers.', 47),
#  ('thinking', 47),
#  ('card', 47),
#  ('bless', 46),
#  ('strong', 46),
#  ('"', 46),
#  ('think', 45),
#  ('into', 44),
#  ('such', 44),
#  ('#coronavirus', 43),
#  ('work', 43),
#  ('done', 43),
#  ('his', 43),
#  ('come', 43),
#  ('•', 43),
#  ('show', 42),
#  ('mums.', 42),
#  ('blessed', 42),
#  ('you’re', 42),
#  ('#socialdistancing', 41),
#  ('old', 41),
#  ('keeping', 41),
#  ('which', 40),
#  ('during', 40),
#  ('me.', 40),
#  ('better', 40),
#  ('right', 40),
#  ('two', 39),
#  ('new', 39),
#  ('http://', 39),
#  ('team', 39),
#  ('super', 39),
#  ('remember', 39),
#  ('bit', 39),
#  ('single', 39),
#  ('away', 39),
#  ('soon', 38),
#  ('few', 38),
#  ('#motherhood', 38),
#  ('making', 38),
#  ('while', 38),
#  ('proud', 38),
#  ('way', 38),
#  ('off', 38),
#  ('thing', 38),
#  ('though', 38),
#  ('before', 38),
#  ('then', 37),
#  ('tell', 37),
#  ('loving', 37),
#  ('strange', 37),
#  ('...', 37),
#  ('tough', 37),
#  ('daughter', 37),
#  ('heart', 37),
#  ('#mothersdayshoutout', 36),
#  ('mother.', 36),
#  ('hug', 36),
#  ('fabulous', 36),
#  ('self', 36),
#  ('did', 36),
#  ('3', 35),
#  ('mum!', 35),
#  ('mothers’', 35),
#  ('dad', 35),
#  ('incredible', 35),
#  ('long', 35),
#  ('anyone', 35),
#  ('mother,', 35),
#  ('different', 35),
#  ('grateful', 35),
#  ('important', 35),
#  ("we're", 35),
#  ('late', 34),
#  ('wait', 34),
#  ('forever', 34),
#  ('thought', 34),
#  ('deserve', 34),
#  ('spending', 34),
#  ('days', 33),
#  ('lives', 33),
#  ('video', 33),
#  ('fantastic', 33),
#  ('should', 33),
#  ('son', 33),
#  ('truly', 33),
#  ("here's", 33),
#  ('each', 33),
#  ('isolation', 33),
#  ('visit', 33),
#  ('birthday', 32),
#  ('safe.', 32),
#  ('precious', 32),
#  ('put', 32),
#  ('#mums', 32),
#  ('said', 32),
#  ('friend', 31),
#  ('her.', 31),
#  ('love,', 31),
#  ('due', 31),
#  ('you!', 31),
#  ('feel', 31),
#  ('favourite', 30),
#  ('place', 30),
#  ('wife', 30),
#  ('might', 30),
#  ('person', 30),
#  ('dear', 30),
#  ('longer', 30),
#  ('time.', 30),
#  ('http://www.', 30),
#  ('sorry', 29),
#  ('ladies', 29),
#  ('gorgeous', 29),
#  ('find', 29),
#  ('whether', 29),
#  ('!!', 29),
#  ('we’re', 29),
#  ('staying', 29),
#  ('help', 29),
#  ('me,', 29),
#  ('#happy', 29),
#  ('step', 29),
#  ('wishes', 28),
#  ('hugs', 28),
#  ('photo', 28),
#  ('something', 28),
#  ("i've", 28),
#  ('same', 28),
#  ('week', 28),
#  ("she's", 28),
#  ('absolute', 28),
#  ('#mom', 27),
#  ('full', 27),
#  ('life.', 27),
#  ('job', 27),
#  ('down', 27),
#  ('nice', 27),
#  ('someone', 27),
#  ('us,', 27),
#  ('why', 27),
#  ('treat', 27),
#  ('#motherslove', 26),
#  ('today!', 26),
#  ('love.', 26),
#  ('#sunday', 26),
#  ('post', 26),
#  ('missing', 26),
#  ('role', 26),
#  ('baby', 26),
#  ('do.', 26),
#  ('distancing', 26),
#  ('whole', 25),
#  ('despite', 25),
#  ("let's", 25),
#  ('virtual', 25),
#  ('anything', 25),
#  ('does', 25),
#  ('saying', 25),
#  ('health', 24),
#  ("you've", 24),
#  ('until', 24),
#  ('friends', 24),
#  ('staff', 24),
#  ('too.', 24),
#  ("that's", 24),
#  ('mummies', 24),
#  ('words', 24),
#  ('cant', 24),
#  ('taking', 24),
#  ('continue', 24),
#  ('seeing', 24),
#  ('everyone.', 24),
#  ('phone', 24),
#  ('morning', 24),
#  ('gave', 24),
#  ('enough', 24),
#  ('world,', 23),
#  ('house', 23),
#  ('child', 23),
#  ('4', 23),
#  ('forget', 23),
#  ('dont', 23),
#  ('mam', 23),
#  ('shout', 23),
#  ('#stayhomesavelives', 23),
#  ('thoughts', 23),
#  ('ur', 23),
#  ('else', 23),
#  ('rock', 23),
#  ('matter', 23),
#  ('healthy', 23),
#  ('nhs', 23),
#  ('everyday', 23),
#  ('taken', 23),
#  ('sad', 23),
#  ('song', 23),
#  ('raising', 23),
#  ('it.', 22),
#  ('left', 22),
#  ('times.', 22),
#  ('home.', 22),
#  ('yet', 22),
#  ('garden', 22),
#  ('#covid19', 22),
#  ('present', 22),
#  ('wished', 22),
#  ('don’t', 22),
#  ('caring', 22),
#  ('once', 22),
#  ('kind', 22),
#  ('walk', 21),
#  ('share', 21),
#  ('challenging', 21),
#  ('queen', 21),
#  ('huge', 21),
#  ('start', 21),
#  ('afternoon', 21),
#  ('#flowers', 21),
#  ('united', 21),
#  ('weeks', 21),
#  ('nothing', 21),
#  ('again', 21),
#  ('picture', 21),
#  ('others', 21),
#  ('..', 21),
#  ('foster', 21),
#  ('forward', 21),
#  ('grandmothers,', 20),
#  ('perfect', 20),
#  ('sister', 20),
#  ('lot', 20),
#  ('moon', 20),
#  ('gone', 20),
#  ('makes', 20),
#  ('figures', 20),
#  ('whatever', 20),
#  ('play', 20),
#  ("i'll", 19),
#  ('given', 19),
#  ('awesome', 19),
#  ('appreciation', 19),
#  ('smile', 19),
#  ('loads', 19),
#  ('since', 19),
#  ('#mummy', 19),
#  ("won't", 19),
#  ('lives.', 19),
#  ('#stayhome', 19),
#  ('extra', 19),
#  ('called', 19),
#  ('mine', 19),
#  ('im', 19),
#  ('–', 19),
#  ('via', 19),
#  ('young', 19),
#  ('bring', 18),
#  ('xxxx', 18),
#  ('live', 18),
#  ('celebrated', 18),
#  ('birth', 18),
#  ('him', 18),
#  ('seen', 18),
#  ('year.', 18),
#  ('distance', 18),
#  ('enedina', 18),
#  ('silva', 18),
#  ('you’ve', 18),
#  ('send', 18),
#  ('across', 18),
#  ("doesn't", 18),
#  ('mean', 18),
#  ('1st', 18),
#  ('watching', 18),
#  ('feeling', 18),
#  ('bad', 18),
#  ('mum’s', 18),
#  ('babies', 18),
#  ('yours', 18),
#  ('end', 18),
#  ('parents', 18),
#  ('sweet', 18),
#  ('are.', 18),
#  ('part', 18),
#  ('mums!', 18),
#  ("couldn't", 18),
#  ('getting', 18),
#  ('*', 18),
#  ('try', 18),
#  ('use', 18),
#  ('enjoying', 18),
#  ('lady', 18),
#  ('whose', 18),
#  ('\u2060', 18),
#  ('protect', 17),
#  ('check', 17),
#  ('#thankyou', 17),
#  ('message', 17),
#  ('royal', 17),
#  ('fun', 17),
#  ('mammies', 17),
#  ('here’s', 17),
#  ('kingdom', 17),
#  ('night', 17),
#  ('couldn’t', 17),
#  ('trans', 17),
#  ('#motherdaughter', 17),
#  ('ma', 17),
#  ('found', 17),
#  ('#covid_19', 17),
#  ('them.', 17),
#  ('all,', 17),
#  ('heavenly', 17),
#  ('went', 17),
#  ("didn't", 17),
#  ('real', 17),
#  ('close', 17),
#  ('tag', 17),
#  ('sent', 16),
#  ('sisters', 16),
#  ('mamas', 16),
#  ('face', 16),
#  ('heaven', 16),
#  ('law', 16),
#  ('sunshine', 16),
#  ('supporting', 16),
#  ('thankful', 16),
#  ('together.', 16),
#  ('@thismorning', 16),
#  ('ask', 16),
#  ("there's", 16),
#  ('\u2063', 16),
#  ('managed', 16),
#  ('change', 16),
#  ('another', 16),
#  ('greatest', 16),
#  ('cards', 16),
#  ('actually', 16),
#  ('#mothersdayuk', 16),
#  ('human', 16),
#  ('now,', 16),
#  ('#women', 16),
#  ('all!', 16),
#  ('must', 16),
#  ('past', 16),
#  ('5', 16),
#  ('stop', 16),
#  ('rest', 16),
#  ("we'll", 16),
#  ('everyone!', 16),
#  ('moment', 16),
#  ('dog', 15),
#  ('strong,', 15),
#  ('beautiful,', 15),
#  ('“', 15),
#  ('life,', 15),
#  ('passed', 15),
#  ('however', 15),
#  ('oh', 15),
#  ('mammy', 15),
#  ('mamma', 15),
#  ('later', 15),
#  ('now.', 15),
#  ('evening', 15),
#  ('definitely', 15),
#  ('needs', 15),
#  ('glad', 15),
#  ('current', 15),
#  ('living', 15),
#  ('#uk', 15),
#  ('beyond', 15),
#  ('female', 15),
#  ('isolating', 15),
#  ('side', 15),
#  ('children.', 15),
#  ('much.', 15),
#  ('facetime', 15),
#  ('ago', 15),
#  ('glass', 15),
#  ('inspiration', 15),
#  ('world!', 15),
#  ('crazy', 15),
#  ('says', 15),
#  ('months', 15),
#  ('spent', 15),
#  ('watch', 14),
#  ('missed', 14),
#  ('|', 14),
#  ('round', 14),
#  ('guys', 14),
#  ('n', 14),
#  ('mam.', 14),
#  ('whilst', 14),
#  ('sacrifices', 14),
#  ('fuck', 14),
#  ('yourself', 14),
#  ('times,', 14),
#  ('means', 14),
#  ('well.', 14),
#  ('brought', 14),
#  ('wanted', 14),
#  ('her,', 14),
#  ('raised', 14),
#  ('taught', 14),
#  ('read', 14),
#  ('!!!', 14),
#  ('aunties', 14),
#  ('wherever', 14),
#  ('far', 14),
#  ('boys', 14),
#  ('ya', 14),
#  ('positive', 14),
#  ('duchess', 14),
#  ('she’s', 14),
#  ('fur', 14),
#  ('become', 14),
#  ('putting', 14),
#  ("i'd", 13),
#  ('between', 13),
#  ('maybe', 13),
#  ('normal', 13),
#  ('second', 13),
#  ('course', 13),
#  ('free', 13),
#  ('nanny', 13),
#  ('editor', 13),
#  ('us!', 13),
#  ('giving', 13),
#  ('asked', 13),
#  ('biological', 13),
#  ('comes', 13),
#  ('window', 13),
#  ('(and', 13),
#  ('everywhere', 13),
#  ('open', 13),
#  ('light', 13),
#  ('2020', 13),
#  ('mom.', 13),
#  ('cheers', 13),
#  ('massive', 13),
#  ('food', 13),
#  ('soon.', 13),
#  ('virus', 13),
#  ('spoilt', 13),
#  ('d', 13),
#  ('talk', 13),
#  ('daughters', 13),
#  ('helping', 13),
#  (':)', 13),
#  ('tonight', 13),
#  ('pics', 13),
#  ('admire', 13),
#  ('facebook', 13),
#  ('angel', 13),
#  ('cherish', 13),
#  ('playing', 13),
#  ('spoil', 13),
#  ('three', 13),
#  ('family,', 13),
#  ("we've", 13),
#  ('nan', 13),
#  ('year,', 13),
#  ('entire', 12),
#  ('day!!', 12),
#  ('saw', 12),
#  ('although', 12),
#  ('brilliant', 12),
#  ('family.', 12),
#  ('memories', 12),
#  ('princess', 12),
#  ('safe,', 12),
#  ('posted', 12),
#  ('#smile', 12),
#  ('ago.', 12),
#  ('i’d', 12),
#  ('motherhood', 12),
#  ('mummy.', 12),
#  ('me!', 12),
#  ('came', 12),
#  ('myself', 12),
#  ('hopefully', 12),
#  ("wouldn't", 12),
#  ('amazing,', 12),
#  ('unusual', 12),
#  ('bed', 12),
#  ('girl', 12),
#  ('weird', 12),
#  ('mother!', 12),
#  ('text', 12),
#  ('half', 12),
#  ('#sundaythoughts', 12),
#  ('keeps', 12),
#  ('carers', 12),
#  ('stories', 12),
#  ('seems', 12),
#  ('used', 12),
#  ('wee', 12),
#  ('girls', 12),
#  ('#loveyou', 12),
#  ('away.', 12),
#  ('mothers!', 12),
#  ('fresh', 12),
#  ('group', 12),
#  ('chat', 12),
#  ('grandmothers', 12),
#  ('و', 12),
#  ("'", 12),
#  ('link', 11),
#  ('least', 11),
#  ('probably', 11),
#  ('relaxing', 11),
#  ('hands', 11),
#  ('”', 11),
#  ('tweet', 11),
#  ('sadly', 11),
#  ('skype', 11),
#  ('#nhs', 11),
#  ('sharing', 11),
#  ('twitter.com/juliahb1/statu', 11),
#  ('unconditional', 11),
#  ('again.', 11),
#  ('nigeria', 11),
#  ('kids,', 11),
#  ('below', 11),
#  ('#selfisolation', 11),
#  ('started', 11),
#  ('joy', 11),
#  ('gonna', 11),
#  ('boy', 11),
#  ('hold', 11),
#  ('biggest', 11),
#  ('coming', 11),
#  ('earth', 11),
#  ('reason', 11),
#  ('children,', 11),
#  ('true', 11),
#  ('#throwback', 11),
#  ('physically', 11),
#  ('supportive', 11),
#  ('apart', 11),
#  ('shes', 11),
#  ('outside', 11),
#  ('dinner', 11),
#  ("haven't", 11),
#  ('one.', 11),
#  ('loves', 11),
#  ('takeaway', 11),
#  ('four', 11),
#  ('#grateful', 11),
#  ('join', 11),
#  ('tea', 11),
#  ('roast', 11),
#  ('twitter', 11),
#  ('let’s', 11),
#  ('stuck', 11),
#  ('using', 11),
#  ('risk', 11),
#  ('customers', 11),
#  ('man', 11),
#  ('selfless', 11),
#  ('ireland', 11),
#  ('inside', 11),
#  ('told', 11),
#  ('me:', 11),
#  ('quiet', 10),
#  ('#isolation', 10),
#  ('lol', 10),
#  ('i’ve', 10),
#  ('mothersday', 10),
#  ('aka', 10),
#  ('time,', 10),
#  ('mom,', 10),
#  ('mind', 10),
#  ('#tatafonaijamothersday', 10),
#  ('photos', 10),
#  ('s/1241676268342521857', 10),
#  ('showing', 10),
#  ('gets', 10),
#  ('#familytime', 10),
#  ('pray', 10),
#  ('buy', 10),
#  ('march', 10),
#  ('strength', 10),
#  ('took', 10),
#  ('yesterday', 10),
#  ('shall', 10),
#  ('including', 10),
#  ('1', 10),
#  ('tomorrow', 10),
#  ('always.', 10),
#  ('above', 10),
#  ('10', 10),
#  ('helped', 10),
#  ('unique', 10),
#  ('mrs', 10),
#  ('pretty', 10),
#  ('do!', 10),
#  ('under', 10),
#  ('friends,', 10),
#  ('sunny', 10),
#  ("isn't", 10),
#  ('much,', 10),
#  ('weekend', 10),
#  ('born', 10),
#  ('worth', 10),
#  ('absolutely', 10),
#  ('shit', 10),
#  ('y', 10),
#  ('relax', 10),
#  ('media', 10),
#  ('instead', 10),
#  ('grow', 10),
#  ('frontline', 10),
#  ('?', 10),
#  ('socially', 10),
#  ('head', 10),
#  ('this.', 10),
#  ('lunch', 10),
#  ('uncertain', 10),
#  ('club', 10),
#  ('#selfisolating', 10),
#  ('received', 10),
#  ('ever.', 10),
#  ('quite', 10),
#  ('story', 10),
#  ('spoiled', 10),
#  ('#illustration', 10),
#  ('parent', 10),
#  ('dads', 10),
#  ('services', 10),
#  ('express', 10),
#  ('funny', 10),
#  ("mummy's", 10),
#  ('adoptive', 10),
#  ('#bestmum', 10),
#  ('needed', 10),
#  ('s', 10),
#  ('realise', 10),
#  ('everywhere.', 10),
#  ('vulnerable', 9),
#  ('members', 9),
#  ('learn', 9),
#  ('#ultimateloveng', 9),
#  ('daily', 9),
#  ('game', 9),
#  ('cake', 9),
#  ('xxxxx', 9),
#  ('wouldn’t', 9),
#  ('trying', 9),
#  ('forgot', 9),
#  ('almost', 9),
#  ('middleton', 9),
#  ('sit', 9),
#  ('filled', 9),
#  ('#baby', 9),
#  ('tears', 9),
#  ('blessing', 9),
#  ('for.', 9),
#  ('gratitude', 9),
#  ('themselves', 9),
#  ('deserves', 9),
#  ('know.', 9),
#  ('decided', 9),
#  ('against', 9),
#  ('#sunshine', 9),
#  ('unable', 9),
#  ('knows', 9),
#  ('strong.', 9),
#  ('#quarantine', 9),
#  ('together,', 9),
#  ('woman,', 9),
#  ('delivered', 9),
#  ('door', 9),
#  ('goes', 9),
#  ('inspired', 9),
#  ('they’re', 9),
#  ('planned', 9),
#  ('mumma', 9),
#  ('local', 9),
#  ('people.', 9),
#  ('fathers', 9),
#  ('sun', 9),
#  ('book', 9),
#  ('service', 9),
#  ('couple', 9),
#  ('leave', 9),
#  ('there!!', 9),
#  ('inspiring', 9),
#  ('them,', 9),
#  ('pic', 9),
#  ('kisses', 9),
#  ('homemade', 9),
#  ('currently', 9),
#  ('future', 9),
#  ('grandma', 9),
#  ("what's", 9),
#  ('amazing!', 9),
#  ('way.', 9),
#  ('everyone,', 9),
#  ('thankyou', 9),
#  ('near', 9),
#  ('rotten', 9),
#  ('mams', 9),
#  ('air', 9),
#  ('hair', 9),
#  ('#ilovemymum', 9),
#  ('belated', 9),
#  ('smiling', 9),
#  ('be,', 9),
#  ('legend', 9),
#  ('yes', 9),
#  ('beauty', 9),
#  ('presents', 9),
#  ('ok', 9),
#  ('na', 9),
#  ('gin', 8),
#  ('rosie', 8),
#  ('#nigeria', 8),
#  ('click', 8),
#  ('#art', 8),
#  ('eat', 8),
#  ('planning', 8),
#  ('hate', 8),
#  ('friend,', 8),
#  ('busy', 8),
#  ('heart.', 8),
#  ('pass', 8),
#  ('catherine', 8),
#  ('bear', 8),
#  ('cannot', 8),
#  ('momma', 8),
#  ('(or', 8),
#  ('@london,', 8),
#  ('well,', 8),
#  ('along', 8),
#  ('spread', 8),
#  ('raise', 8),
#  ('father', 8),
#  ('order', 8),
#  ('soul', 8),
#  ('men', 8),
#  ('dedication', 8),
#  ('cancer', 8),
#  ('granted', 8),
#  ('waiting', 8),
#  ('news', 8),
#  ('jesus', 8),
#  ('owe', 8),
#  ('short', 8),
#  ...]

# %%
vocab_to_int = {w:i+1 for i,(w,c) in enumerate(sorted_words)}
vocab_to_int['others'] = len(sorted_words)+1
print(vocab_to_int, vocab_to_int['others'])
# Out:
# {'to': 1, 'happy': 2, 'day': 3, 'the': 4, 'and': 5, 'mothers': 6, 'you': 7, 'all': 8, 'a': 9, '#mothersday': 10, 'my': 11, '…': 12, 'of': 13, 'i': 14, 'for': 15, 'in': 16, 'we': 17, 'https://www.': 18, '.': 19, 'love': 20, 'your': 21, 'are': 22, 'out': 23, 'is': 24, 'our': 25, 'this': 26, "mother's": 27, 'mother’s': 28, 'mum': 29, 'with': 30, 'have': 31, 'be': 32, 'so': 33, 'mums': 34, 'her': 35, 'but': 36, 'from': 37, 'who': 38, 'that': 39, 'at': 40, 'me': 41, 'on': 42, '&': 43, 'it': 44, 'today': 45, 'not': 46, 'there': 47, 'amazing': 48, 'us': 49, 'as': 50, 'hope': 51, 'mother': 52, 'thank': 53, 'she': 54, 'their': 55, 'https://': 56, '#mothersday2020': 57, 'wonderful': 58, 'do': 59, 'those': 60, 'very': 61, 'one': 62, '#happymothersday': 63, 'best': 64, 'just': 65, 'like': 66, 'know': 67, 'beautiful': 68, 'wish': 69, 'can': 70, 'stay': 71, 'was': 72, 'day!': 73, 'lovely': 74, ',': 75, 'or': 76, 'will': 77, 'every': 78, 'much': 79, 'always': 80, 'see': 81, '#motheringsunday': 82, 'had': 83, 'safe': 84, 'when': 85, 'they': 86, 'how': 87, 'being': 88, 'no': 89, 'if': 90, 'special': 91, 'up': 92, 'world': 93, 'everyone': 94, 'day.': 95, 'would': 96, 'time': 97, 'an': 98, 'what': 99, 'them': 100, 'been': 101, 'great': 102, 'women': 103, 'celebrate': 104, 'has': 105, 'may': 106, 'by': 107, 'here': 108, 'more': 109, 'get': 110, 'wishing': 111, 'these': 112, 'there.': 113, "it's": 114, 'keep': 115, 'still': 116, '#love': 117, 'everything': 118, 'some': 119, 'x': 120, 'most': 121, 'family': 122, 'even': 123, "i'm": 124, 'without': 125, 'you.': 126, 'good': 127, 'mums,': 128, 'say': 129, 'children': 130, 'mom': 131, 'other': 132, 'over': 133, '#mum': 134, 'make': 135, 'take': 136, 'about': 137, 'now': 138, 'there!': 139, 'thanks': 140, 'loved': 141, '#mothers': 142, 'today.': 143, 'xx': 144, 'also': 145, 'little': 146, 'am': 147, 'year': 148, "you're": 149, 'ones': 150, 'people': 151, 'through': 152, 'able': 153, '#happymothersday2020': 154, 'especially': 155, 'made': 156, 'mothers,': 157, 'could': 158, "mothers'": 159, 'home': 160, 'mum,': 161, 'uk': 162, 'many': 163, "can't": 164, 'life': 165, 'please': 166, 'woman': 167, 'care': 168, 'doing': 169, '#family': 170, 'give': 171, 'never': 172, 'only': 173, 'it’s': 174, 'than': 175, 'mum.': 176, 'world.': 177, 'there,': 178, 'you,': 179, 'xxx': 180, 'times': 181, 'working': 182, 'u': 183, 'appreciate': 184, 'got': 185, 'miss': 186, 'big': 187, 'god': 188, 'want': 189, 'because': 190, 'go': 191, 'sunday': 192, 'call': 193, 'day,': 194, 'first': 195, '#mother': 196, 'enjoy': 197, 'mummy': 198, 'after': 199, 'ever': 200, 'lost': 201, 'today,': 202, 'lots': 203, "mum's": 204, 'together': 205, 'going': 206, 'well': 207, "don't": 208, 'around': 209, 'having': 210, 'sending': 211, 'i’m': 212, 'own': 213, 'look': 214, 'both': 215, 'hard': 216, 'flowers': 217, 'all.': 218, 'last': 219, 'sure': 220, 'mama': 221, 'back': 222, '#stayathome': 223, 'need': 224, 'kids': 225, '#staysafe': 226, 'years': 227, 'families': 228, 'its': 229, 'any': 230, 'were': 231, 'social': 232, 'lucky': 233, 'mothering': 234, 'where': 235, '#covidー19': 236, 'can’t': 237, 'things': 238, 'celebrating': 239, 'support': 240, 'let': 241, 'us.': 242, '2': 243, 'next': 244, 'spend': 245, 'too': 246, 'really': 247, 'he': 248, 'looking': 249, 'difficult': 250, 'moms': 251, 'mothers.': 252, 'thinking': 253, 'card': 254, 'bless': 255, 'strong': 256, '"': 257, 'think': 258, 'into': 259, 'such': 260, '#coronavirus': 261, 'work': 262, 'done': 263, 'his': 264, 'come': 265, '•': 266, 'show': 267, 'mums.': 268, 'blessed': 269, 'you’re': 270, '#socialdistancing': 271, 'old': 272, 'keeping': 273, 'which': 274, 'during': 275, 'me.': 276, 'better': 277, 'right': 278, 'two': 279, 'new': 280, 'http://': 281, 'team': 282, 'super': 283, 'remember': 284, 'bit': 285, 'single': 286, 'away': 287, 'soon': 288, 'few': 289, '#motherhood': 290, 'making': 291, 'while': 292, 'proud': 293, 'way': 294, 'off': 295, 'thing': 296, 'though': 297, 'before': 298 ...

# %%
def tweets_int_func(tweets_punc):
    tweets_int = []
    for tweet in tweets_punc:
        
        r = [vocab_to_int[w] for w in tweet.split(' ') if w ]
        tweets_int.append(r)
        
    return np.array(tweets_int)

# %%
tweets_int = tweets_int_func(tweets_punc)
print(tweets_int.shape)
# Out:
# (3235,)

# %%
def pad_sequence(seq_length, tweets_int):
    features = np.zeros((len(tweets_int), seq_length), dtype = int)
    
    for i, tweet in enumerate(tweets_int):
        tweet_len = len(tweet)
        
        if tweet_len <= seq_length:
            zeros = list(np.zeros(seq_length - tweet_len))
            new = zeros + tweet
            
        elif tweet_len > seq_length:
            new = tweet[:seq_length]
        features[i,:] = np.array(new)
        
    return features

# %%
seq_length = 64
inp = pad_sequence(seq_length, tweets_int)
print(inp.shape)
# Out:
# (3235, 64)

# %%
print(type(sentiments.values), sentiments.values.shape)
# Out:
# <class 'numpy.ndarray'> (3235,)

# %%
def tweets2rep(total_words, embed_dim, feature):
    embed = nn.Embedding(total_words, embed_dim)
    tweet_rep = torch.zeros(feature.shape[1],feature.shape[0], embed_dim)
    tweet_ = embed(torch.tensor(feature))
    tweet_rep = tweet_.permute(1,0,2)
    return tweet_rep

# %%
tweet_rep = tweets2rep(total_words, 512, inp)
print(tweet_rep.shape)
# Out:
# torch.Size([64, 3235, 512])

# %%
def class2rep(sentiments):
    sentiment_labels = torch.tensor(sentiments, dtype = torch.float32)
    return torch.reshape(sentiment_labels, (sentiment_labels.shape[0],1))

# %%
sentiment_labels = class2rep(sentiments.values)
print(sentiment_labels.shape)
# Out:
# torch.Size([3235, 1])

# %%
print(sentiment_labels.dtype)
# Out:
# torch.float32

# %% [markdown]
# ### Sentiment Analysis

# %%
class sentimentAnalysisRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(sentimentAnalysisRNN, self).__init__()
        
        self.hidden_size = hidden_size
        
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        self.tanh = nn.Tanh()
        
    def forward(self, inp, hidden):
        combined = torch.cat((inp, hidden), 1)
        hidden = self.i2h(combined)
        output = self.i2o(combined)
        output = self.tanh(output)
        
        return output, hidden
    
    def init_hidden(self):
        return torch.zeros(1, self.hidden_size)

# %%
n_hidden = 256
embed_dim = 512
output_size = 1
rnn = sentimentAnalysisRNN(embed_dim, n_hidden, output_size)

# %%
input_tweet = tweets2rep(total_words, embed_dim, inp[0:1,:])
print(input_tweet.shape)
# Out:
# torch.Size([64, 1, 512])

# %%
print(tweets[0], '\n', sentiment_labels[0])
# Out:
# Happy #MothersDay to all you amazing mothers out there! I know it's hard not being able to see your mothers today but it's on all of us to do what we can to protect the most vulnerable members of our society. #BeatCoronaVirus pic.twitter.com/va4nFjFQ5B
#  tensor([0])

# %%
hidden = torch.zeros(1, n_hidden)
output, next_hidden = rnn(input_tweet[0], hidden)

# %%
hidden = torch.zeros(1, n_hidden)
inp_tweet = tweet_rep[:, 1:2, :]
print(hidden.shape, inp_tweet.shape)

for word in inp_tweet:
    #print(word.shape)
    out, hidden = rnn(word, hidden)
    
print(output)
# Out:
# torch.Size([1, 256]) torch.Size([64, 1, 512])
# tensor([[0.6717]], grad_fn=<TanhBackward>)

# %%
print(output)
# Out:
# tensor([[0.6717]], grad_fn=<TanhBackward>)

# %%
from torch.utils.data import DataLoader, TensorDataset
train_data = TensorDataset(tweet_rep, sentiment_labels)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-d4de6ea29b9d> in <module>
#       1 from torch.utils.data import DataLoader, TensorDataset
# ----> 2 train_data = TensorDataset(tweet_rep, sentiment_labels)
#
# /usr/anaconda/lib/python3.7/site-packages/torch/utils/data/dataset.py in __init__(self, *tensors)
#     156
#     157     def __init__(self, *tensors):
# --> 158         assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors)
#     159         self.tensors = tensors
#     160
#
# AssertionError:

# %%
import random

def randomChoice(n):
    return random.randint(0, n - 1)

def randomTrainingExample():
    training_size = len(tweet_rep)
    choice = randomChoice(training_size)
    sentiment_label = sentiment_labels[choice:choice+1,:]
    tweet = tweet_rep[:, choice:choice+1,:]
    return tweet, sentiment_label

# %%
x, y = randomTrainingExample()
print(x.shape, y.shape)
# Out:
# torch.Size([64, 1, 512]) torch.Size([1, 1])

# %% [markdown]
# ### Training RNN

# %%
import torch.optim as optim
learning_rate = 0.01
criterion = nn.MSELoss()
optim = optim.Adam(rnn.parameters(), lr = learning_rate)

# %%
def train(net, tweet, sentiment):
    hidden = net.init_hidden()
    net.zero_grad()
    hidden = hidden.detach_()
    hidden = Variable(hidden.data, requires_grad = True)
    for word in tweet:
        output, hidden = net(word, hidden)
        
    loss = criterion(output, sentiment[0])
    loss.backward(retain_graph = True)
    
    for p in net.parameters():
        p.data.add_(p.grad.data, alpha = -learning_rate)
        
    return output, loss.item()

# %%
import time
import math

n_iters = 10
print_every = 2
plot_every = 1

current_loss = 0
all_losses = []

def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s = s - m*60
    return '%dm %ds' %(m,s)

# %%
from torch.autograd import Variable
start = time.time()
for iter in range(1, n_iters + 1):
    tweet, sentiment = randomTrainingExample()
    output, loss = train(rnn, tweet, sentiment)
    current_loss = current_loss + loss
    
    if iter%print_every == 0:
        correct = 'x'
        if sentiment == output[0]:
            correct = ',/'
        print(sentiment, output, '-----',correct)
        print('time: ',timeSince(start))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-62-3df9fbb446ff> in <module>
#       3 for iter in range(1, n_iters + 1):
#       4     tweet, sentiment = randomTrainingExample()
# ----> 5     output, loss = train(rnn, tweet, sentiment)
#       6     current_loss = current_loss + loss
#       7
#
# <ipython-input-60-4d430477dfc9> in train(net, tweet, sentiment)
#       8
#       9     loss = criterion(output, sentiment[0])
# ---> 10     loss.backward(retain_graph = True)
#      11
#      12     for p in net.parameters():
#
# /usr/anaconda/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# /usr/anaconda/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# RuntimeError: Trying to backward through the graph a second time, but the buffers have already been freed. Specify retain_graph=True when calling backward the first time.

# %%
class sentiment_analysis_lstm(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm_cell = nn.LSTM(input_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)
        self.tanh = nn.Tanh()
        
    def forward(self, batch_inp, hidden):
        out, hidden = self.lstm_cell(batch_inp, hidden)
        
        output = self.h2o(hidden[0].view(-1, self.hidden_size))
        output = self.tanh(output)
        return output, hidden
    
    def init_hidden(self, batch_size = 1):
        return (torch.zeros(batch_size, 1, self.hidden_size), torch.zeros(batch_size, 1,self.hidden_size))

# %%
n_hidden = 256
input_size = 512
net = sentiment_analysis_lstm(input_size, n_hidden, 1)

# %%
batch_size = 10
train_loader = DataLoader(train_data, shuffle = True, batch_size = batch_size)

# %%
def batched_dataloader(npoints, tweet_rep, sentiment_label, verbose=False, device = 'cpu'):
    tweets = []
    sentiments = []
    tweet_lengths = []
    
    for i in range(npoints):
        index_ = np.random.randint(len(X_))
        tweet, sentiment = tweet_rep[index_,:,:], sentiment_label[index_,:]
        X_lengths.append(len(tweet))
    max_length = max(X_lengths)
    
    tweets_rep = tweet_rep[n_points,:,:].to(device)
    langs_rep = sentiment_label[n_points,:].to(device)
    
    padded_tweets_rep = torch.nn.utils.rnn.pack_padded_sequence(names_rep, X_lengths, enforce_sorted = False)
    
    if verbose:
        print(names_rep.shape, padded_names_rep.data.shape)
        print('--')
    
    if verbose:
        print(names)
        print_char(names_rep)
        print('--')
    
    if verbose:
        print_char(padded_names_rep.data)
        print('Lang Rep', langs_rep.data)
        print('Batch sizes', padded_names_rep.batch_sizes)
    
    
    return padded_names_rep.to(device), langs_rep

# %%
def train_batch(net, opt, criterion,batch_size, dataiter, device = 'cpu'):
    
    net.train().to(device)
    opt.zero_grad()
    
    batch_input, batch_groundtruth = dataiter.next()
    h0 = net.init_hidden(batch_size)
    print(h0[0].shape)
    output, hidden = net(batch_input.view(batch_size, 1,-1), h0)
    print(output.shape, hidden[0].shape)
    loss = criterion(output, batch_groundtruth)
    
    loss.backward()
    opt.step()
    return loss

# %%
def train_setup(net,lr = 0.01, n_batches = 100, batch_size = 10, momentum = 0.9, display_freq = 5, device = 'cpu'):
    net = net.to(device)
    criterion = nn.MSELoss()
    opt = optim.SGD(net.parameters(), lr = lr, momentum = momentum)
    
    loss_arr = np.zeros(n_batches + 1)
    
    for i in range(n_batches):
        dataiter = iter(train_loader)
        loss_arr[i+1] = (loss_arr[i]*i + train_batch(net, opt, criterion, batch_size, dataiter, device))/(i+1)
        
        if i%display_freq == display_freq - 1:
            clear_output(wait=True)
            
            print('Iteration: ', i, '\tLoss: ', loss_arr[i])
            plt.figure()
            plt.plot(loss_arr[1:i], '-*')
            plt.xlabel('Iteration')
            plt.ylabel('Loss')
            
            plt.show()
            print('\n\n')

# %%
train_setup(net, batch_size = 1)
# Out:
# torch.Size([1, 1, 256])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-133-1ffc7fa8d745> in <module>
# ----> 1 train_setup(net, batch_size = 1)
#
# <ipython-input-132-01ebc568f78b> in train_setup(net, lr, n_batches, batch_size, momentum, display_freq, device)
#       8     for i in range(n_batches):
#       9         dataiter = iter(train_loader)
# ---> 10         loss_arr[i+1] = (loss_arr[i]*i + train_batch(net, opt, criterion, batch_size, dataiter, device))/(i+1)
#      11
#      12         if i%display_freq == display_freq - 1:
#
# <ipython-input-131-77b9693fb081> in train_batch(net, opt, criterion, batch_size, dataiter, device)
#       7     h0 = net.init_hidden(batch_size)
#       8     print(h0[0].shape)
# ----> 9     output, hidden = net(batch_input.view(batch_size, 1,-1), h0)
#      10     print(output.shape, hidden[0].shape)
#      11     loss = criterion(output, batch_groundtruth)
#
# /usr/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-127-1aacacfcda96> in forward(self, batch_inp, hidden)
#       9
#      10     def forward(self, batch_inp, hidden):
# ---> 11         out, hidden = self.lstm_cell(batch_inp, hidden)
#      12
#      13         output = self.h2o(hidden[0].view(-1, self.hidden_size))
#
# /usr/anaconda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/anaconda/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     554             hx = self.permute_hidden(hx, sorted_indices)
#     555
# --> 556         self.check_forward_args(input, hx, batch_sizes)
#     557         if batch_sizes is None:
#     558             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#
# /usr/anaconda/lib/python3.7/site-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     506     def check_forward_args(self, input, hidden, batch_sizes):
#     507         # type: (Tensor, Tuple[Tensor, Tensor], Optional[Tensor]) -> None
# --> 508         self.check_input(input, batch_sizes)
#     509         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     510
#
# /usr/anaconda/lib/python3.7/site-packages/torch/nn/modules/rnn.py in check_input(self, input, batch_sizes)
#     157             raise RuntimeError(
#     158                 'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
# --> 159                     self.input_size, input.size(-1)))
#     160
#     161     def get_expected_hidden_size(self, input, batch_sizes):
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 512, got 327680

# %%
tweet_rep.shape
# Out:
# torch.Size([3235, 64, 512])

# %%
inputs = [torch.randn(1,3) for _ in range(5)]
for i in inputs
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-e4ff5a11bf2f> in <module>
#       1 inputs = [torch.randn(1,3) for _ in range(5)]
# ----> 2 print(inputs.shape)
#
# AttributeError: 'list' object has no attribute 'shape'
